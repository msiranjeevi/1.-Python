# %%
#1.Find the error in the following Python code:
#Corretion: instead of math it's Math
import math
print(math.sqrt(16))
# Out:
# 4.0

# %%
#2.Find the error in the following Python code:
#Since the x is not declared, argument should be passed so that increment of x can be done
def my_function(x):
    x += 5
    print(x)

x = 10

# %%
#argument passed to do the increment inside the function
my_function(2)
# Out:
# 7

# %%
#3.x = 5
#instead of comparision, asignment operator found

if x == 10:
    print("x is 10")
# Out:
# x is 10

# %%
#4. 
#This is sorted the list and can return only None.
#Sort it and then print it will give the sorted list
numbers = [5, 3, 8, 2]
numbers.sort()
print(numbers)
# Out:
# [2, 3, 5, 8]

# %%
#5.
def square(n):
    p = n * n
    print(p)
#print(square(4))

# %%
square(4)
# Out:
# 16

# %%
#6. Tuples are immutable, cannot change
my_tuple = (1, 2, 3)
#my_tuple[1] = 5
#in case if we want to change,
my_list = [1, 2, 3]
my_list[1] = 5
print(my_list)
# Out:
# [1, 5, 3]

# %%
#7. %s - string, %d - integer, instead of 2 args one is found
name = "Alice"
age = 25
print("My name is %s and I am %d years old" % (name,age))
# Out:
# My name is Alice and I am 25 years old

# %%
#8. operator "is" will not eturn anything if the both objects has same memory
#So compare it with == operator to check the elements are same
a = [1, 2, 3]
b = [1, 2, 3]
if a == b:
    print("Lists are equal")
# Out:
# Lists are equal

# %%
#9.end value is lower that start value, so interchange those
for i in range(1, 5):
    print(i)
# Out:
# 1
# 2
# 3
# 4

# %%
#10.name was not in quotes in print statement
student = {"name": "John", "age": 20}
print(student["name"])
# Out:
# John
