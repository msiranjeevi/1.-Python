# %% [markdown]
# Print

# %%
print("welcome to python")
# Out:
# welcome to python

# %% [markdown]
# Print with Escape Sequence

# %%
print("welcome to Gen AI \n-By Hope AI")
# Out:
# welcome to Gen AI
# -By Hope AI

# %% [markdown]
# Print with tab

# %%
print("welcome to Gen AI \t By Hope AI")
# Out:
# welcome to Gen AI 	 By Hope AI
