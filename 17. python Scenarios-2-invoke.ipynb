# %%
from pythonScenario2 import ps2

# %%
ps2.trans(-400)
# Out:
# You are fined due to negative balance

# %%
ps2.passcode(999994)
# Out:
# ['9', '9', '9', '9', '9', '4']
# [9, 9, 9, 9, 9, 4]
# Valid passcode, you can access your locker

# %%
ps2.passcode(999995)
# Out:
# ['9', '9', '9', '9', '9', '5']
# [9, 9, 9, 9, 9, 5]
# Invalid passcode, entry restricted!!!

# %%
ps2.otp(90921)
# Out:
# 90921
# ['9', '0', '9', '2', '1']
# ['1', '2', '9', '0', '9']
# 12909

# %%
ps2.pnc(2)
# Out:
# Its a prime

# %%
ps2.fac(5)
# Out:
# 120

# %%
ps2.arm(191)
# Out:
# ['1', '9', '1']
# [1, 9, 1]
# Its not an armstrong number

# %%
ps2.pwd("media")
# Out:
# 'aedim'

# %%
ps2.bina(990)
# Out:
# '1111011110'

# %%
sen="we are the united world in the constitution"
ps2.lwo(sen)
# Out:
# ['we', 'are', 'the', 'united', 'world', 'in', 'the', 'constitution']
# The longest word is: constitution

# %%
ps2.ana("world","rowld")
# Out:
# 'Its an anagram'
