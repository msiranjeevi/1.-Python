# %%
#Function without return
#no1=float(input("Enter number 1:"))
#no2=float(input("Enter number 2"))
no1=100
no2=200
def opera():
    
    #Addition
    a_res = no1 + no2
    print("Addition Result:", a_res)

    #Subtraction
    s_res = no1 - no2
    print("Subtraction Result:", s_res)

    #Multiplication
    m_res = no1 * no2
    print("Multiplication Result:", m_res)

    #Division
    d_res = no1 / no2
    print("Division Result:,", d_res)

    #Floor Division
    d_res = no1 // no2
    print("Floor Division Result:", d_res)

    #Modulo
    m_res = no1 % no2
    print("Modulo Result is:", m_res)

    #Power
    p_res = no1 ** no2
    print("Square value is:", p_res)

    #input number investigation
    if (no1 % 2) == 0:
            print("no1 is a even number")
    else:
            print("no1 is not an even number")

# %%
opera()
# Out:
# Addition Result: 300
# Subtraction Result: -100
# Multiplication Result: 20000
# Division Result:, 0.5
# Floor Division Result: 0
# Modulo Result is: 100
# Square value is: ...
# no1 is a even number

# %%
#Function with return
no1=float(input("Enter number 1:"))
no2=float(input("Enter number 2"))
#no1=100
#no2=200
def opera(no1,no2):
    
    #Addition
    a_res = no1 + no2
    print("Addition Result:", a_res)

    #Subtraction
    s_res = no1 - no2
    print("Subtraction Result:", s_res)

    #Multiplication
    m_res = no1 * no2
    print("Multiplication Result:", m_res)

    #Division
    d_res = no1 / no2
    print("Division Result:,", d_res)

    #Floor Division
    d_res = no1 // no2
    print("Floor Division Result:", d_res)

    #Modulo
    m_res = no1 % no2
    print("Modulo Result is:", m_res)

    #Power
    p_res = no1 ** no2
    print("Square value is:", p_res)

    #input number investigation
    if (no1 % 2) == 0:
            print("no1 is a even number")
    else:
            print("no1 is not an even number")   
    return(no1,no2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[44], line 2
#       1 #Function with return
# ----> 2 no1=float(input("Enter number 1:"))
#       3 no2=float(input("Enter number 2"))
#       4 #no1=100
#       5 #no2=200
#
# ValueError: could not convert string to float: ''

# %%
opera(no1,no2)
# Out:
# Addition Result: 3.0
# Subtraction Result: -1.0
# Multiplication Result: 2.0
# Division Result:, 0.5
# Floor Division Result: 0.0
# Modulo Result is: 1.0
# Square value is: 1.0
# no1 is not an even number
# (1.0, 2.0)

# %%
nos=opera(no1,no2)
# Out:
# Addition Result: 27.0
# Subtraction Result: -3.0
# Multiplication Result: 180.0
# Division Result:, 0.8
# Floor Division Result: 0.0
# Modulo Result is: 12.0
# Square value is: 1.5407021574586368e+16
# no1 is a even number

# %%
nos
# Out:
# (12.0, 15.0)

# %%
nos
hno = nos[0]
for i in nos:
    if i > hno:
        hno = i
        
print("highest element is:", hno)
# Out:
# highest element is: 15.0

# %%
#Calculate CGP using 3 functions
#total for 5 subjects
def totalMarks():
    m1=int(input("Enter your English mark:"))
    m2=int(input("Enter your Social mark:"))
    m3=int(input("Enter your Science mark:"))
    m4=int(input("Enter your Maths mark:"))
    m5=int(input("Enter your AI    mark:"))
    total = m1 + m2 + m3 + m4 + m5
    return total

# %%
#Assigning total marks
total=totalMarks()
total
# Out:
# 375

# %%
#Calculate average
def avgMarks(total):
    return total / 5

# %%
#Assigning average
average=avgMarks(total)

# %%
def cgp(average):
    return average / 10

# %%
cgpa = cgp(average)
print(cgpa)
# Out:
# 7.5

# %%
def grade(total,average,cgpa):
    if total >= 450 and average >= 90 and cgpa >= 9.0:
        return "A+ Grade"
    elif total >= 400 and average >= 80 and cgpa >= 8.0:
        return "A Grade"
    elif total >= 350 and average >= 70 and cgpa >= 7.0:
        return "B Grade"
    elif total >= 300 and average >= 60 and cgpa >= 6.0:
        return "C Grade"
    else:
        return "Fail"

# %%
ga=grade(total,average,cgpa)
print(ga)
# Out:
# B Grade

# %% [markdown]
# CREATING ALL THE FUNCTIONS

# %%
#Calculate CGP using 3 functions
#total for 5 subjects
def totalMarks():
    m1=int(input("Enter your English mark:"))
    m2=int(input("Enter your Social mark:"))
    m3=int(input("Enter your Science mark:"))
    m4=int(input("Enter your Maths mark:"))
    m5=int(input("Enter your AI    mark:"))
    total = m1 + m2 + m3 + m4 + m5
    return total

#Calculate average
def avgMarks(total):
    return total / 5

#Calculate cgp    
def cgp(average):
    return average / 10

def grade(total,average,cgpa):
    if total >= 450 and average >= 90 and cgpa >= 9.0:
        return "A+ Grade"
    elif total >= 400 and average >= 80 and cgpa >= 8.0:
        return "A Grade"
    elif total >= 350 and average >= 70 and cgpa >= 7.0:
        return "B Grade"
    elif total >= 300 and average >= 60 and cgpa >= 6.0:
        return "C Grade"
    else:
        return "Fail"

# %% [markdown]
# INVOKING ALL THE FUNCTIONS WITH ITS ARGUMENTS

# %%
#Assigning total marks and invoking totalMarks() function
total=totalMarks()
print("######SCORE SUMMARY DETAILS:######")
print("Your total mark for 5 subjects is:", total)

#Assigning average and invoking avgMArks() function with "total" as an argument
average=avgMarks(total)
print("Your average score is:", average)

#Assigning cgpa and invoking cgp() function with "average" as an argument
cgpa = cgp(average)
print("Your CGPA is:", cgpa)

#Assigning grade and invoking grade() function with "total,average and cgpa" as arguments
ga=grade(total,average,cgpa)
print("Your grade level is:",ga)
# Out:
# ######SCORE SUMMARY DETAILS:######
# Your total mark for 5 subjects is: 461
# Your average score is: 92.2
# Your CGPA is: 9.22
# Your grade level is: A+ Grade
