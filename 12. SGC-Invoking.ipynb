# %% [markdown]
# **********STUDENT GRADE CALCULATOR APPLICATION**********

# %%
#from file_name import class_name
from studentGradeCalculator import SGC

# %%
SGC.totalMarks()
# Out:
# 411

# %%
SGC.avgMarks(411)
# Out:
# 82.2

# %%
SGC.cgp(82.2)
# Out:
# 8.22

# %%
SGC.grade(411,82.2,8.22)
# Out:
# 'A Grade'
