# %%
from Function_Assignment_2 import FA2

# %%
FA2.triangle()
# Out:
# Height is: 10.2
# Base is: 12.3
# Formula applied: 0.5 * height * base
# Area of triangle: 62.73
# side 1 is: 12.2
# side 2 is: 13.2
# side 3 is: 14.2
# perimeter value is: 39.6

# %%
FA2.oe()
# Out:
# 'Its an odd number'

# %%
FA2.eli()
# Out:
# 'You are not eligible for marriage'
