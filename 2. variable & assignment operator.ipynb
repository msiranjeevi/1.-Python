# %% [markdown]
# Variable and its assignments

# %%
pant=1500
trouser=2400
tax=127
total_bill=pant + trouser + tax
print("Total bill is:" , total_bill)
# Out:
# Total bill is: 4027

# %%
print("****************************")
print("Welcome to the Grasp Store")
print("****************************")
pant=1500
print("The price of the pant is:" , pant)
trouser=2400
print("The price of the trouser is:" , trouser)
tax=127
print("The tax applicable is:" , tax)
total_bill=pant + trouser + tax
print("Total bill is:" , total_bill)
# Out:
# ****************************
# Welcome to the Grasp Store
# ****************************
# The price of the pant is: 1500
# The price of the trouser is: 2400
# The tax applicable is: 127
# Total bill is: 4027

# %%
print("****************************")
print("Welcome to the Grasp Store")
print("****************************")
pant=int(input("Whats the price of the pant:"))
print("The price of the pant is:" , pant)
trouser=int(input("Whats the price of the trouser:"))
print("The price of the trouser is:" , trouser)
tax=int(input("Whats the tax applicable:"))
print("The tax applicable is:" , tax)
total_bill=pant + trouser + tax
print("------------------------------")
print("Total bill is:" , total_bill)
print("------------------------------")
# Out:
# ****************************
# Welcome to the Grasp Store
# ****************************
# The price of the pant is: 1200
# The price of the trouser is: 2300
# The tax applicable is: 127
# ------------------------------
# Total bill is: 3627
# ------------------------------
